# %% [markdown]
# <a href="https://colab.research.google.com/github/holaamigoo/University/blob/main/Extra_Tasks/Ex_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_contact(phone_book: dict) -> dict:
  '''
  Добавляет контакт (имя и номер телефона) в телефонную книгу.

  phone_book: Телефонная книга
  return: Копия телефонной книги с добавленным контактом
  '''
  name = input("Введите имя контакта:")
  phone = input("Введите номер телефона:")
  standartized_name = standartize_name(name)
  standartized_phone = standartize_phone(phone)
  new_phone_book = phone_book.copy()
  new_phone_book[standartized_name] = standartized_phone
  print("Контакт успешно добавлен!")
  return new_phone_book


def delete_contact(phone_book: dict) -> dict:
  '''
  Удаляет контакт из телефонной книги. Поиск осуществляется по имени контакта.

  pnone_book: Телефонная книга
  return: Копия телефонной книги, в которой удалили контакт.
  '''
  name = input("Введите имя контакта:")
  standartized_name = standartize_name(name)
  if standartized_name in phone_book:
    new_phone_book = phone_book.copy()
    del new_phone_book[standartized_name]
    print("Контакт удален!")
    return new_phone_book
  else:
    print("Контакт не найден!")
    return phone_book


def view_contact(phone_book: dict) -> dict:
  '''
  Процедура. Выводит построчно все контакты (имя - номер) в телефонной книге.

  phone_book: Телефонная книга
  return: None
  '''
  if not phone_book:
    print("Телефонная книга пуста!")
  else:
    for name, phone in phone_book.items():
      print(f"{name}: {phone}")


def edit_contact(phone_book: dict) -> dict:
  '''
  Изменяет номер телефона у существующего контакта
  в телефонной книге. Если контакт не найден, телефонная книга
  не изменяется.

  phone_boook: Телефонная книга
  return: Копия телефонной книги с отредактированным контактом.
  '''
  name = input("Введите имя контакта:")
  standartized_name = standartize_name(name)

  if standartized_name in phone_book:
    phone = input("Введите номер телефона:")
    standartized_phone = standartize_phone(phone)
    new_phone_book = phone_book.copy()
    new_phone_book[standartized_name] = standartized_phone
    print("Номер телефона успешно изменен!")
    return new_phone_book
  else:
    print("Контакт не наден!")
    return phone_book


def standartize_name(name: str) -> str:
  '''
  Стандартизирует имя контакта (все слова прописываются с заглавной буквы).

  name: Имя контакта
  return: Стандартизированное имя контакта.
  '''
  return name.title()


def standartize_phone(phone: str) -> str:
  '''
  Стандартизирует номер телефона (преобразует в формат +71234567890)

  phone: Номер телефона
  return: Стандартизированный номер телефона
  '''
  phone_digits = ''.join(char for char in phone if char.isdigit())

  if len(phone_digits) == 10:
    return "+7" + phone_digits

  elif len(phone_digits) == 11:
    return "+7" + phone_digits[1:]

  return phone_digits


def menu() -> None:
  '''
  Запускает бесконечный цикл для взаимодействия пользователя с телефонной книгой.
  Выводит иструкции и отчеты пользователю.
  '''
  phone_book = {}
  while True:
    print("Выберите функцию:\n", "1. Создать контакт", "2. Удалить контакт",
        "3. Показать список контактов", "4. Изменить номер", "5. Выход\n", sep="\n")
    print()

    choice = input("Введите номер функции: ")
    if choice == '1':
      phone_book = add_contact(phone_book)
      print()
    elif choice == '2':
      phone_book = delete_contact(phone_book)
      print()
    elif choice == '3':
      view_contact(phone_book)
      print()
    elif choice == '4':
      phone_book = edit_contact(phone_book)
      print()
    elif choice == '5':
      print("Выход из программы")
      break
    else:
      print("Неверный выбор! Попробуйте снова.")


menu()
# Out:
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
#
# Введите номер функции: 1
# Введите имя контакта:катя
# Введите номер телефона:9165215648
# Контакт успешно добавлен!
#
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
#
# Введите номер функции: 1
# Введите имя контакта:евгений
# Введите номер телефона:8-499-749-25-52
# Контакт успешно добавлен!
#
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
#
# Введите номер функции: 4
# Введите имя контакта:катя
# Введите номер телефона:1234567890
# Номер телефона успешно изменен!
#
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
#
# Введите номер функции: 2
# Введите имя контакта:евгений
# Контакт удален!
#
# Выберите функцию:
#
# ...

# %%
def add_contact(name_input, number_input):
  name_input = name_input.title()
  number_input = "+7" + number_input
  list_of_contacts[name_input] = number_input

def delete_contact(name_input):
  name_input = name_input.title()
  list_of_contacts.pop(name_input)

def open_phone_book():
  for k, v in list_of_contacts.items():
        print(k, v)

def edit_contact(name_input, number_input):
  name_input = name_input.title()
  number_input = "+7" + number_input
  list_of_contacts[name_input] = number_input



list_of_contacts = {}

def main():
  print("Выберите функцию:\n", "1. Создать контакт", "2. Удалить контакт",
        "3. Показать список контактов", "4. Изменить номер", "5. Выход\n", sep="\n")
  while True:
    command = input("Введите номер функции:")
    match command:
      case "1":
        name_input = input("Введите название для контакта:")
        number_input = input("Введите номер телефона:")
        add_contact(name_input, number_input)
        print("Контакт успешно добавлен!")
      case "2":
        name_input = input("Введите имя контакта, который хотите удалить:")
        delete_contact(name_input)
        print("Контакт удален")
      case "3":
        print("Список контактов:")
        open_phone_book()
      case "4":
        name_input = input("Введите название для контакта:")
        number_input = input("Введите номер телефона:")
        edit_contact(name_input, number_input)
        print("Контакт успешно изменен!")
      case "5":
        print("Выход из списка контактов!")
        break

main()
# Out:
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
# Введите номер функции:1
# Введите название для контакта:Катя
# Введите номер телефона:9160022768
# Контакт успешно добавлен!
# Введите номер функции:1
# Введите название для контакта:Стас Михайлов
# Введите номер телефона:9151234567
# Контакт успешно добавлен!
# Введите номер функции:3
# Список контактов:
# Катя +79160022768
# Стас Михайлов +79151234567
# Введите номер функции:4
# Введите название для контакта:Катя
# Введите номер телефона:4991508769
# Контакт успешно изменен!
# Введите номер функции:2
# Введите имя контакта, который хотите удалить:Стас Михайлов
# Контакт удален
# Введите номер функции:3
# Список контактов:
# Катя +74991508769
# Введите номер функции:5
# Выход из списка контактов!

# %%
list_of_contacts = {}
print("Выберите функцию:\n", "1. Создать контакт", "2. Удалить контакт",
        "3. Показать список контактов", "4. Изменить номер", "5. Выход\n", sep="\n")
while True:
  command = input("Введите номер функции:")
  match command:
    case "1":
      name_input = input("Введите название для контакта:")
      name_input = name_input.title()
      number_input = input("Введите номер телефона:")
      number_input = "+7" + number_input
      list_of_contacts[name_input] = number_input
      print("Контакт успешно добавлен!")
    case "2":
      name_input = input("Введите имя контакта, который хотите удалить:")
      name_input = name_input.title()
      list_of_contacts.pop(name_input)
      print("Контакт удален")
    case "3":
      print("Список контактов:")
      for k, v in list_of_contacts.items():
        print(k, v)
    case "4":
      name_input = input("Введите название для контакта:")
      name_input = name_input.title()
      number_input = input("Введите номер телефона:")
      number_input = "+7" + number_input
      list_of_contacts[name_input] = number_input
      print("Контакт успешно изменен!")
    case "5":
      print("Выход из списка контактов!")
      break
# Out:
# Выберите функцию:
#
# 1. Создать контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер
# 5. Выход
#
# Введите номер функции:1
# Введите название для контакта:лена иванова
# Введите номер телефона:9161234567
# Контакт успешно добавлен!
# Введите номер функции:3
# Список контактов:
# Лена Иванова +79161234567
# Введите номер функции:4
# Введите название для контакта:лена иванова
# Введите номер телефона:9160002211
# Контакт успешно изменен!
# Введите номер функции:3
# Список контактов:
# Лена Иванова +79160002211
# Введите номер функции:2
# Введите имя контакта, который хотите удалить:лена иванова
# Контакт удален
# Введите номер функции:3
# Список контактов:
# Введите номер функции:5
# Выход из списка контактов!
